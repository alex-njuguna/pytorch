# %% [markdown]
# <a href="https://colab.research.google.com/github/alex-njuguna/pytorch/blob/main/wine_quality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("/content/WineQT.csv")
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
# Check if there are null values
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
# Check for duplicated data
data.duplicated().sum()
# Out:
# 0

# %%
# Check data types
data.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# Id                        int64
# dtype: object

# %%
# Find numbers of cols and rows
data.shape
# Out:
# (1143, 13)

# %%
# statistical definition of the data
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Create a histogram for quality against count
plt.figure(figsize=(12, 6))
sns.histplot(data=data, x='quality')
plt.show()

# %%
data[data['quality'] == 5].value_counts()
# Out:
# fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  density  pH    sulphates  alcohol  quality  Id
# 5.0            1.040             0.24         1.6             0.050      32.0                 96.0                  0.99340  3.74  0.62       11.5     5        553     1
# 8.9            0.310             0.57         2.0             0.111      26.0                 85.0                  0.99710  3.26  0.53       9.7      5        185     1
# 8.6            0.470             0.30         3.0             0.076      30.0                 135.0                 0.99760  3.30  0.53       9.4      5        313     1
#                                  0.27         2.3             0.055      14.0                 28.0                  0.99516  3.18  0.80       11.2     5        928     1
# ...

# %%
# scatter plot for residual sugar against quality
plt.figure(figsize=(12, 6))
sns.scatterplot(data=data, x='residual sugar', y='quality')
plt.show()

# %%
# Effect of free sulphhur dioxide and total sulphur dioxide on quality
plt.figure(figsize=(12, 6))
sns.scatterplot(data=data, x='total sulfur dioxide', y='free sulfur dioxide', hue='quality')
plt.show()

# %%
data.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.250728     0.673157
# volatile acidity          -0.250728          1.000000    -0.544187
# citric acid                0.673157         -0.544187     1.000000
# residual sugar             0.171831         -0.005751     0.175815
# chlorides                  0.107889          0.056336     0.245312
# free sulfur dioxide       -0.164831         -0.001962    -0.057589
# total sulfur dioxide      -0.110628          0.077748     0.036871
# density                    0.681501          0.016512     0.375243
# pH                        -0.685163          0.221492    -0.546339
# sulphates                  0.174592         -0.276079     0.331232
# alcohol                   -0.075055         -0.203909     0.106250
# quality                    0.121970         -0.407394     0.240821
# Id                        -0.275826         -0.007892    -0.139011
#
# ...

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(data.corr(), annot=True)
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import StandardScaler

# %%
# Spliting data into features and tragets
X = data.drop(columns = ['quality', "Id"], axis=1)
y = data["quality"]
# X.head()

# %%
# Normalizing the features to have features with the same weight(std 0 - mean 1)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)
X_scaled.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0      -0.521580          0.939332    -1.365027       -0.466421  -0.231395
# 1      -0.292593          1.941813    -1.365027        0.050060   0.234247
# 2      -0.292593          1.273492    -1.161568       -0.171289   0.107253
# 3       1.653789         -1.399789     1.483400       -0.466421  -0.252560
# 4      -0.521580          0.939332    -1.365027       -0.466421  -0.231395
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0            -0.450467             -0.363610  0.555854  1.270695  -0.573658
# 1             0.915920              0.643477  0.036165 -0.708928   0.130881
# 2            -0.060071              0.246745  0.140103 -0.325775  -0.045254
# 3             0.135127              0.429852  0.659792 -0.964363  -0.456235
# 4            -0.450467             -0.363610  0.555854  1.270695  -0.573658
#
#     alcohol        Id
# 0 -0.963382 -1.735618
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
X_train.shape
# Out:
# (914, 12)

# %%
y_train.shape
# Out:
# (914,)

# %%
X_test.shape
# Out:
# (229, 12)

# %%
y_test.shape
# Out:
# (229,)
